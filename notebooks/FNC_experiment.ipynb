# %% [markdown]
# # Import libraries
#
# Use conda env with tensorflow-gpu and keras
#
# This notebook contains the following:
#
# 1. Load training data, split and train network
#     - find data here:
#     https://s3.console.aws.amazon.com/s3/object/gcw-rimbunio-common-input-data-dev/input_data/other/pixel_based_training_data/south_east_asia/
# 2. Test inference on imagery
#     - use GBDX
#     - use imagery as tif downloaded from GBDX
#
#
# find model example file: https://drive.google.com/drive/u/0/folders/1JXnWrSEp0mTt8JtqWh2ATBzXjkm7ZkVX

# %%
# import the necessary packages
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import numpy as np
import geojson
import dask
import os

import tensorflow as tf

from keras.layers import Dense, Dropout, Activation
from keras.models import Sequential
from keras.optimizers import Adam
from keras import regularizers
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
from keras.callbacks import Callback
from keras import backend as K

from keras.applications.vgg16 import VGG16
from keras.models import Input, Model
from keras.layers import Add, Conv2D, Conv2DTranspose

import cv2
import glob
import json
import numpy as np
import rasterio

from datetime import datetime
from functools import partial
from shapely.geometry import box, mapping
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from skimage import filters

# Instantiating an Interface object automatically logs you in to the GBDX platform
from gbdxtools.task import env
from gbdxtools import CatalogImage
from gbdxtools import Interface
gbdx = Interface()

# %% [markdown]
# # Get prebuild training dataset

# %%
path = '../../data/trainings_data_waterbodies/data_non_acomp_all_polygons_2020-03-26 12:37:01.698516.csv'


nr_search = path.split('/')[-1].split('_')[4]

nr_search


# Reading the raw data into a Pandas DataFrame

import pandas as pd

data_raw = pd.read_csv(path).drop('Unnamed: 0', axis = 1).drop(['x','y'], axis= 1)

# First we rename the columns of our dataset 

# Bands
# coastal = data[0]
# blue = data[1]
# green = data[2]
# yellow = data[3]
# red = data[4]
# red_edge = data[5]
# nir1 = data[6]
# nir2 = data[7]

    # select variables
property_names = ['cloudCover',
                 'multiResolution',
                 'targetAzimuth',
                 # 'timestamp',
                 'sunAzimuth',
                 'offNadirAngle',
                 # 'platformName',
                 'sunElevation',
                 # 'scanDirection',
                 'panResolution']

data_raw.columns = ['coastal','blue','green','yellow','red','red_edge','nir1','nir2',] + property_names  + ['label']

# Here we will calculate the indices with the band data we already have

data_raw['ndvi'] = (data_raw.nir1 - data_raw.red)/(data_raw.nir1 + data_raw.red)
data_raw['ndwi'] = (data_raw.green - data_raw.nir1)/(data_raw.green + data_raw.nir1)

data_raw['wwi'] = (data_raw.coastal-data_raw.nir2)/(data_raw.coastal+data_raw.nir2+10e-5)

data_clean = data_raw


all_variables = ['coastal','blue','green','yellow','red','red_edge','nir1','nir2',] + property_names + ['ndvi','ndwi', 'wwi']

i = 0 
for variable in all_variables:
    print(i, variable)
    i = i + 1
    
variable_selection = range(17)

all_variables = [all_variables[i] for i in variable_selection]

data = data_clean[all_variables].values

# Normalize training data to between 0 and 1
try:
    min_data =  np.nanmin(data)
    max_data = np.nanmax(data)
    data = (data - min_data) / (max_data - min_data)
except Exception as e:
    print(e)
# Out:
# 0 coastal
# 1 blue
# 2 green
# 3 yellow
# 4 red
# 5 red_edge
# 6 nir1
# 7 nir2
# 8 cloudCover
# 9 multiResolution
# 10 targetAzimuth
# 11 sunAzimuth
# 12 offNadirAngle
# 13 sunElevation
# 14 panResolution
# 15 ndvi
# 16 ndwi
# 17 wwi

# %%
# check data 
data_clean
# Out:
#         coastal    blue   green  yellow    red  red_edge    nir1    nir2  \
# 0        1157.0   996.0   867.0   680.0  606.0     355.0   320.0   195.0
# 1        1428.0  1253.0  1064.0   846.0  732.0     445.0   371.0   239.0
# 2        1223.0  1056.0   904.0   688.0  597.0     368.0   321.0   190.0
# 3        1149.0   985.0   854.0   654.0  563.0     346.0   300.0   178.0
# 4        1263.0  1042.0   884.0   686.0  581.0     409.0   331.0   198.0
# ...         ...     ...     ...     ...    ...       ...     ...     ...
# 306822   1731.0  1464.0  1225.0   984.0  883.0    1163.0  1682.0  1228.0
# 306823   1686.0  1427.0  1146.0   914.0  834.0     938.0  1328.0   954.0
# 306824   1684.0  1431.0  1183.0   948.0  854.0    1084.0  1648.0  1198.0
# 306825   1681.0  1428.0  1161.0   932.0  844.0    1024.0  1502.0  1084.0
# 306826   1723.0  1470.0  1237.0   995.0  896.0    1138.0  1699.0  1223.0
#
#         cloudCover  multiResolution  targetAzimuth  sunAzimuth  offNadirAngle  \
# 0                4         1.990745     353.378480   42.406155      16.204758
# 1                4         1.990745     353.378480   42.406155      16.204758
# 2                4         1.990745     353.378480   42.406155      16.204758
# 3                4         1.990745     353.378480   42.406155      16.204758
# 4                4         1.990745     353.378480   42.406155      16.204758
# ...            ...              ...            ...         ...            ...
# 306822          36         2.158924      50.913406  114.023445      23.307102
# 306823          36         2.158924      50.913406  114.023445      23.307102
# 306824          36         2.158924      50.913406  114.023445      23.307102
# 306825          36         2.158924      50.913406  114.023445      23.307102
# 306826          36         2.158924      50.913406  114.023445      23.307102
#
#         sunElevation  panResolution      label      ndvi      ndwi       wwi
# 0           53.59690       0.499102      water -0.308855  0.460826  0.711538
# 1           53.59690       0.499102      water -0.327289  0.482927  0.713257
# 2           53.59690       0.499102      water -0.300654  0.475918  0.731069
# 3           53.59690       0.499102      water -0.304751  0.480069  0.731726
# 4           53.59690       0.499102      water -0.274123  0.455144  0.728953
# ...              ...            ...        ...       ...       ...       ...
# 306822      64.75944       0.541851  non_water  0.311501 -0.157207  0.169990
# 306823      64.75944       0.541851  non_water  0.228492 -0.073565  0.277273
# 306824      64.75944       0.541851  non_water  0.317346 -0.164253  0.168633
# 306825      64.75944       0.541851  non_water  0.280477 -0.128051  0.215913
# 306826      64.75944       0.541851  non_water  0.309441 -0.157357  0.169722
#
# [306827 rows x 19 columns]

# %%
X = data 

# Similarly, we can extract the labels
y = data_clean['label'].values == 'water'

X.shape
# Out:
# (306827, 17)

# %%
# x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=0, shuffle=True, stratify=labels)

# First split the data samples into training and validation sets
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

print('')
print('Training Data Shape: ', X_train.shape)   # Convert to 2-D tensor -> X_train[nb_samples, nb_channels]
print('Training Data Dtype: ', X_train.dtype)
print('Training Labels Shape: ', y_train.shape) # Convert to 1-D tensor -> y_train[nb_samples]
print('Training Labels Dtype: ', y_train.dtype)

# Second, split the the validation data into validation and testing sets
X_validation, X_test, y_validation, y_test = train_test_split(X_validation, y_validation, test_size=0.33, random_state=42, stratify=y_validation)

print('')
print('Validation Data Shape: ',X_validation.shape)  # Convert to 2-D tensor -> X_validation[nb_samples, nb_channels]
print('Validation Data Shape: ', X_validation.dtype)
print('Validation Labels: ', y_validation.shape)     # Convert to 1-D tensor -> y_validation[nb_samples]
print('Validation Labels: ', y_validation.dtype)

print('')
print('Test Data Shape: ',X_test.shape)  # Convert to 2-D tensor -> testData[nb_samples, nb_channels]
print('Test Data Shape: ', X_test.dtype)
print('Test Labels: ', y_test.shape)     # Convert to 1-D tensor -> testLabels[nb_samples]
print('Test Labels: ', y_test.dtype)
# Out:
# Training Data Shape:  (214778, 17)
# Training Data Dtype:  float64
# Training Labels Shape:  (214778,)
# Training Labels Dtype:  bool
#
# Validation Data Shape:  (61672, 17)
# Validation Data Shape:  float64
# Validation Labels:  (61672,)
# Validation Labels:  bool
#
# Test Data Shape:  (30377, 17)
# Test Data Shape:  float64
# Test Labels:  (30377,)
# Test Labels:  bool

# %%
np.savez_compressed('../../data/bfalg_data/train.npz',
                    X_train=X_train,
                    y_train=y_train)
np.savez_compressed('../../data/bfalg_data/validation.npz',
                    X_validation=X_validation,
                    y_validation=y_validation)
np.savez_compressed('../../data/bfalg_data/test.npz',
                    X_test=X_test,
                    y_test=y_test)
np.savez_compressed('../../data/bfalg_data/minMax.npz',
                    min_data=min_data,
                    max_data=max_data)

# %% [markdown]
# ### Define the Deep Learning Model.
#
# The model is a shallow multi-layer perceptron (MLP), using only fully-connnected (Dense) layers. We also use dropout layers and ReLu activation. The reason why we used drop-out layers is that we found the model's predictive capability to be less prone to false-alarm on 'blue-topped' buildings or other man-made structures.

# %%
# Define the Multi-layer Perceptron (MLP) neural network model
def create_baseline(dimensions):
    # Create model
    model = Sequential()
    model.add(Dense(dimensions, input_dim=dimensions, activation="relu", kernel_initializer="glorot_uniform"))
    model.add(Dropout(0.25))
    model.add(Dense(4, activation="relu", kernel_initializer="glorot_uniform"))
    model.add(Dense(2, activation="relu", kernel_initializer="glorot_uniform"))
    model.add(Dense(1, activation='sigmoid'))
    
    # Compile model
    opt = Adam(decay=0.000005)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

    # Display the model summary
    model.summary()

    # Return the newly constructed network architecture
    return model

# %% [markdown]
# ### Create custom callback to terminate early
#
# This custom Keras callback will terminate early if either the minimal learning rate has been achieved (i.e., plateaus) or the maximum number of Epochs has been reached.

# %%
# Create custom callback to terminate early if minimum learning rate 
# has been achieved or the maximum number of Epochs has been reached
class EarlyStoppingByLearningRate(Callback):
    def __init__(self, min_lr=0., max_epochs=100, verbose=0):
        super(Callback, self).__init__()
        self.min_lr = min_lr
        self.max_epochs = max_epochs
        self.verbose = verbose
        self.init_lr=0
        self.curr_lr=0
        self.decay=0
        self.iterations=0

    def on_epoch_end(self, epoch, logs={}):
        self.init_lr = K.get_value(self.model.optimizer.lr)
        self.decay = K.get_value(self.model.optimizer.decay)
        self.iterations = K.get_value(self.model.optimizer.iterations)
        self.curr_lr = self.init_lr * (1. / (1. + self.decay * self.iterations))

        if self.curr_lr < self.min_lr or epoch == self.max_epochs:
            if self.verbose > 0:
                print("The current LR = {0:10.8f} at Epoch = {1:05d}".format(self.curr_lr, epoch))
            self.model.stop_training = True

# %%
# Specify the list of training 'batch' sizes
batch_sizes = [200] # [200, 300, 400, 500] # [100]
n_samples, dimensions= X.shape

verbose = 1

for (cnt, batch_size) in enumerate(batch_sizes):

    print("Training the water-land classes predictive model ...")

    # Load our MLP binary classifier model
    model = create_baseline(dimensions) # create_baseline2(800, 800, transfer_learning = True, l_r = 0.0001)

    # Specify the minimum learning rate, the maximum number of epochs, and the batch size
    min_learning_rate = 0.000001
    max_epochs = 200

    # Use reduce learning rate if validation loss plateaus
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                                  verbose=verbose,
                                  factor=0.1,
                                  patience=25,
                                  min_lr=min_learning_rate)

    # Use checkpointer callback to save the model everytime the validation accuracy increases
    weights = '../../data/bfalg_models/bfalg_' + 'batchSize_' + str(batch_size) + '_Epoch-{epoch:05d}-Val_acc-{accuracy:.5f}_' + 'weights.hdf5'
    checkpointer = ModelCheckpoint(weights, 
                                   monitor='accuracy', 
                                   verbose=verbose,
                                   save_best_only=True,
                                   mode='max')

    # Early stopping by learning rate callback
    earlyStop = EarlyStoppingByLearningRate(min_lr=min_learning_rate, 
                                            max_epochs=max_epochs,
                                            verbose=verbose)

    # Create list of all of the callbacks
    callbacks_list = [reduce_lr, checkpointer, earlyStop]
    
    history = model.fit(X_train, 
                        y_train,
                        batch_size=batch_size,
                        epochs=max_epochs, 
                        callbacks=callbacks_list,
                        shuffle=True,
                        validation_data=(X_validation, y_validation))
    
    # Evaluate and display the accuracy using the test data
    loss, accuracy = model.evaluate(X_test, y_test, batch_size=batch_size, verbose=verbose)

    # Output the loss and accuracy on the held-out testing set
    print()
    print("Test loss: {:.4f}%".format(loss))
    print("Test accuracy: {:.4f}%".format(accuracy * 100))
    
    # List all data in history
    print(history.history.keys())
# Out:
# Training the water-land classes predictive model ...
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 17)                306
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 17)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 4)                 72
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 10
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 391
# Trainable params: 391
# Non-trainable params: 0
# _________________________________________________________________
# Train on 214778 samples, validate on 61672 samples
# Epoch 1/200
# 214778/214778 [==============================] - 11s 53us/step - loss: 0.4379 - accuracy: 0.8117 - val_loss: 0.3002 - val_accuracy: 0.8953
#
# Epoch 00001: accuracy improved from -inf to 0.81167, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00001-Val_acc-0.81167_weights.hdf5
# Epoch 2/200
# 214778/214778 [==============================] - 10s 47us/step - loss: 0.2815 - accuracy: 0.8999 - val_loss: 0.2577 - val_accuracy: 0.9063
#
# Epoch 00002: accuracy improved from 0.81167 to 0.89989, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00002-Val_acc-0.89989_weights.hdf5
# Epoch 3/200
# 214778/214778 [==============================] - 9s 41us/step - loss: 0.2592 - accuracy: 0.9047 - val_loss: 0.2471 - val_accuracy: 0.9085
#
# Epoch 00003: accuracy improved from 0.89989 to 0.90466, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00003-Val_acc-0.90466_weights.hdf5
# Epoch 4/200
# 214778/214778 [==============================] - 7s 31us/step - loss: 0.2506 - accuracy: 0.9065 - val_loss: 0.2409 - val_accuracy: 0.9088
#
# Epoch 00004: accuracy improved from 0.90466 to 0.90655, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00004-Val_acc-0.90655_weights.hdf5
# Epoch 5/200
# 214778/214778 [==============================] - 7s 31us/step - loss: 0.2381 - accuracy: 0.9094 - val_loss: 0.2070 - val_accuracy: 0.9238
#
# Epoch 00005: accuracy improved from 0.90655 to 0.90938, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00005-Val_acc-0.90938_weights.hdf5
# Epoch 6/200
# 214778/214778 [==============================] - 8s 36us/step - loss: 0.2133 - accuracy: 0.9196 - val_loss: 0.1986 - val_accuracy: 0.9259
#
# Epoch 00006: accuracy improved from 0.90938 to 0.91964, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00006-Val_acc-0.91964_weights.hdf5
# Epoch 7/200
# 214778/214778 [==============================] - 10s 47us/step - loss: 0.2049 - accuracy: 0.9219 - val_loss: 0.1894 - val_accuracy: 0.9319
#
# Epoch 00007: accuracy improved from 0.91964 to 0.92194, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00007-Val_acc-0.92194_weights.hdf5
# Epoch 8/200
# 214778/214778 [==============================] - 12s 58us/step - loss: 0.1978 - accuracy: 0.9241 - val_loss: 0.1805 - val_accuracy: 0.9318
#
# Epoch 00008: accuracy improved from 0.92194 to 0.92412, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00008-Val_acc-0.92412_weights.hdf5
# Epoch 9/200
# 214778/214778 [==============================] - 12s 57us/step - loss: 0.1906 - accuracy: 0.9260 - val_loss: 0.1723 - val_accuracy: 0.9363
#
# Epoch 00009: accuracy improved from 0.92412 to 0.92604, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00009-Val_acc-0.92604_weights.hdf5
# Epoch 10/200
# 214778/214778 [==============================] - 12s 55us/step - loss: 0.1833 - accuracy: 0.9295 - val_loss: 0.1637 - val_accuracy: 0.9410
#
# Epoch 00010: accuracy improved from 0.92604 to 0.92946, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00010-Val_acc-0.92946_weights.hdf5
# Epoch 11/200
# 214778/214778 [==============================] - 14s 67us/step - loss: 0.1775 - accuracy: 0.9327 - val_loss: 0.1572 - val_accuracy: 0.9433
#
# Epoch 00011: accuracy improved from 0.92946 to 0.93269, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00011-Val_acc-0.93269_weights.hdf5
# Epoch 12/200
# 214778/214778 [==============================] - 12s 57us/step - loss: 0.1725 - accuracy: 0.9343 - val_loss: 0.1521 - val_accuracy: 0.9479
#
# Epoch 00012: accuracy improved from 0.93269 to 0.93427, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00012-Val_acc-0.93427_weights.hdf5
# Epoch 13/200
# 214778/214778 [==============================] - 12s 56us/step - loss: 0.1679 - accuracy: 0.9365 - val_loss: 0.1503 - val_accuracy: 0.9451
#
# Epoch 00013: accuracy improved from 0.93427 to 0.93648, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00013-Val_acc-0.93648_weights.hdf5
# Epoch 14/200
# 214778/214778 [==============================] - 11s 52us/step - loss: 0.1655 - accuracy: 0.9376 - val_loss: 0.1474 - val_accuracy: 0.9488
#
# Epoch 00014: accuracy improved from 0.93648 to 0.93762, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00014-Val_acc-0.93762_weights.hdf5
# Epoch 15/200
# 214778/214778 [==============================] - 12s 56us/step - loss: 0.1632 - accuracy: 0.9389 - val_loss: 0.1424 - val_accuracy: 0.9528
#
# Epoch 00015: accuracy improved from 0.93762 to 0.93891, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00015-Val_acc-0.93891_weights.hdf5
# Epoch 16/200
# 214778/214778 [==============================] - 13s 59us/step - loss: 0.1588 - accuracy: 0.9408 - val_loss: 0.1439 - val_accuracy: 0.9476
#
# Epoch 00016: accuracy improved from 0.93891 to 0.94082, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00016-Val_acc-0.94082_weights.hdf5
# Epoch 17/200
# 214778/214778 [==============================] - 12s 58us/step - loss: 0.1551 - accuracy: 0.9430 - val_loss: 0.1375 - val_accuracy: 0.9524
#
# Epoch 00017: accuracy improved from 0.94082 to 0.94304, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00017-Val_acc-0.94304_weights.hdf5
# Epoch 18/200
# 214778/214778 [==============================] - 13s 61us/step - loss: 0.1518 - accuracy: 0.9444 - val_loss: 0.1309 - val_accuracy: 0.9551
#
# Epoch 00018: accuracy improved from 0.94304 to 0.94444, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00018-Val_acc-0.94444_weights.hdf5
# Epoch 19/200
# 214778/214778 [==============================] - 14s 63us/step - loss: 0.1476 - accuracy: 0.9460 - val_loss: 0.1249 - val_accuracy: 0.9598
#
# Epoch 00019: accuracy improved from 0.94444 to 0.94602, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00019-Val_acc-0.94602_weights.hdf5
# Epoch 20/200
# 214778/214778 [==============================] - 12s 58us/step - loss: 0.1449 - accuracy: 0.9472 - val_loss: 0.1224 - val_accuracy: 0.9596
#
# Epoch 00020: accuracy improved from 0.94602 to 0.94715, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00020-Val_acc-0.94715_weights.hdf5
# Epoch 21/200
# 214778/214778 [==============================] - 14s 66us/step - loss: 0.1426 - accuracy: 0.9485 - val_loss: 0.1237 - val_accuracy: 0.9605
#
# Epoch 00021: accuracy improved from 0.94715 to 0.94850, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00021-Val_acc-0.94850_weights.hdf5
# Epoch 22/200
# 214778/214778 [==============================] - 11s 52us/step - loss: 0.1391 - accuracy: 0.9496 - val_loss: 0.1188 - val_accuracy: 0.9576
#
# Epoch 00022: accuracy improved from 0.94850 to 0.94963, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00022-Val_acc-0.94963_weights.hdf5
# Epoch 23/200
# 214778/214778 [==============================] - 12s 58us/step - loss: 0.1382 - accuracy: 0.9489 - val_loss: 0.1172 - val_accuracy: 0.9601
#
# Epoch 00023: accuracy did not improve from 0.94963
# Epoch 24/200
# 214778/214778 [==============================] - 10s 48us/step - loss: 0.1364 - accuracy: 0.9499 - val_loss: 0.1144 - val_accuracy: 0.9601
#
# Epoch 00024: accuracy improved from 0.94963 to 0.94991, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00024-Val_acc-0.94991_weights.hdf5
# Epoch 25/200
# 214778/214778 [==============================] - 8s 39us/step - loss: 0.1358 - accuracy: 0.9497 - val_loss: 0.1124 - val_accuracy: 0.9635
#
# Epoch 00025: accuracy did not improve from 0.94991
# Epoch 26/200
# 214778/214778 [==============================] - 11s 51us/step - loss: 0.1337 - accuracy: 0.9505 - val_loss: 0.1161 - val_accuracy: 0.9632
#
# Epoch 00026: accuracy improved from 0.94991 to 0.95049, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00026-Val_acc-0.95049_weights.hdf5
# Epoch 27/200
# 214778/214778 [==============================] - 12s 57us/step - loss: 0.1330 - accuracy: 0.9511 - val_loss: 0.1118 - val_accuracy: 0.9626
#
# Epoch 00027: accuracy improved from 0.95049 to 0.95114, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00027-Val_acc-0.95114_weights.hdf5
# Epoch 28/200
# 214778/214778 [==============================] - 11s 53us/step - loss: 0.1322 - accuracy: 0.9514 - val_loss: 0.1103 - val_accuracy: 0.9627
#
# Epoch 00028: accuracy improved from 0.95114 to 0.95135, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00028-Val_acc-0.95135_weights.hdf5
# Epoch 29/200
# 214778/214778 [==============================] - 10s 49us/step - loss: 0.1310 - accuracy: 0.9517 - val_loss: 0.1157 - val_accuracy: 0.9611
#
# Epoch 00029: accuracy improved from 0.95135 to 0.95175, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00029-Val_acc-0.95175_weights.hdf5
# Epoch 30/200
# 214778/214778 [==============================] - 12s 54us/step - loss: 0.1297 - accuracy: 0.9520 - val_loss: 0.1104 - val_accuracy: 0.9638
#
# Epoch 00030: accuracy improved from 0.95175 to 0.95202, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00030-Val_acc-0.95202_weights.hdf5
# Epoch 31/200
# 214778/214778 [==============================] - 10s 47us/step - loss: 0.1303 - accuracy: 0.9517 - val_loss: 0.1091 - val_accuracy: 0.9618
#
# Epoch 00031: accuracy did not improve from 0.95202
# Epoch 32/200
# 214778/214778 [==============================] - 10s 46us/step - loss: 0.1302 - accuracy: 0.9515 - val_loss: 0.1096 - val_accuracy: 0.9615
#
# Epoch 00032: accuracy did not improve from 0.95202
# Epoch 33/200
# 214778/214778 [==============================] - 12s 57us/step - loss: 0.1287 - accuracy: 0.9525 - val_loss: 0.1053 - val_accuracy: 0.9636
#
# Epoch 00033: accuracy improved from 0.95202 to 0.95246, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00033-Val_acc-0.95246_weights.hdf5
# Epoch 34/200
# 214778/214778 [==============================] - 12s 56us/step - loss: 0.1286 - accuracy: 0.9526 - val_loss: 0.1121 - val_accuracy: 0.9583
#
# Epoch 00034: accuracy improved from 0.95246 to 0.95257, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00034-Val_acc-0.95257_weights.hdf5
# Epoch 35/200
# 214778/214778 [==============================] - 10s 45us/step - loss: 0.1276 - accuracy: 0.9526 - val_loss: 0.1093 - val_accuracy: 0.9639
#
# Epoch 00035: accuracy improved from 0.95257 to 0.95264, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00035-Val_acc-0.95264_weights.hdf5
# Epoch 36/200
# 214778/214778 [==============================] - 9s 44us/step - loss: 0.1268 - accuracy: 0.9531 - val_loss: 0.1058 - val_accuracy: 0.9644
#
# Epoch 00036: accuracy improved from 0.95264 to 0.95307, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00036-Val_acc-0.95307_weights.hdf5
# Epoch 37/200
# 214778/214778 [==============================] - 10s 49us/step - loss: 0.1268 - accuracy: 0.9528 - val_loss: 0.1132 - val_accuracy: 0.9604
#
# Epoch 00037: accuracy did not improve from 0.95307
# Epoch 38/200
# 214778/214778 [==============================] - 11s 53us/step - loss: 0.1256 - accuracy: 0.9528 - val_loss: 0.1102 - val_accuracy: 0.9622
#
# Epoch 00038: accuracy did not improve from 0.95307
# Epoch 39/200
# 214778/214778 [==============================] - 12s 57us/step - loss: 0.1241 - accuracy: 0.9541 - val_loss: 0.1012 - val_accuracy: 0.9658
#
# Epoch 00039: accuracy improved from 0.95307 to 0.95407, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00039-Val_acc-0.95407_weights.hdf5
# Epoch 40/200
# 214778/214778 [==============================] - 10s 45us/step - loss: 0.1250 - accuracy: 0.9537 - val_loss: 0.1023 - val_accuracy: 0.9648
#
# Epoch 00040: accuracy did not improve from 0.95407
# Epoch 41/200
# 214778/214778 [==============================] - 9s 44us/step - loss: 0.1246 - accuracy: 0.9536 - val_loss: 0.1049 - val_accuracy: 0.9629
#
# Epoch 00041: accuracy did not improve from 0.95407
# Epoch 42/200
# 214778/214778 [==============================] - 9s 43us/step - loss: 0.1254 - accuracy: 0.9530 - val_loss: 0.1058 - val_accuracy: 0.9639
#
# Epoch 00042: accuracy did not improve from 0.95407
# Epoch 43/200
# 214778/214778 [==============================] - 15s 68us/step - loss: 0.1247 - accuracy: 0.9531 - val_loss: 0.1050 - val_accuracy: 0.9652
#
# Epoch 00043: accuracy did not improve from 0.95407
# Epoch 44/200
# 214778/214778 [==============================] - 14s 64us/step - loss: 0.1242 - accuracy: 0.9539 - val_loss: 0.1023 - val_accuracy: 0.9643
#
# Epoch 00044: accuracy did not improve from 0.95407
# Epoch 45/200
# 214778/214778 [==============================] - 14s 64us/step - loss: 0.1248 - accuracy: 0.9533 - val_loss: 0.1008 - val_accuracy: 0.9650
#
# Epoch 00045: accuracy did not improve from 0.95407
# Epoch 46/200
# 214778/214778 [==============================] - 15s 70us/step - loss: 0.1237 - accuracy: 0.9540 - val_loss: 0.0985 - val_accuracy: 0.9657
#
# Epoch 00046: accuracy did not improve from 0.95407
# Epoch 47/200
# 214778/214778 [==============================] - 11s 53us/step - loss: 0.1233 - accuracy: 0.9537 - val_loss: 0.1056 - val_accuracy: 0.9621
#
# Epoch 00047: accuracy did not improve from 0.95407
# Epoch 48/200
# 214778/214778 [==============================] - 11s 49us/step - loss: 0.1218 - accuracy: 0.9544 - val_loss: 0.1005 - val_accuracy: 0.9663
#
# Epoch 00048: accuracy improved from 0.95407 to 0.95441, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00048-Val_acc-0.95441_weights.hdf5
# Epoch 49/200
# 214778/214778 [==============================] - 11s 50us/step - loss: 0.1230 - accuracy: 0.9541 - val_loss: 0.1033 - val_accuracy: 0.9651
#
# Epoch 00049: accuracy did not improve from 0.95441
# Epoch 50/200
# 214778/214778 [==============================] - 9s 42us/step - loss: 0.1205 - accuracy: 0.9549 - val_loss: 0.0997 - val_accuracy: 0.9644
#
# Epoch 00050: accuracy improved from 0.95441 to 0.95489, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00050-Val_acc-0.95489_weights.hdf5
# Epoch 51/200
# 214778/214778 [==============================] - 9s 41us/step - loss: 0.1227 - accuracy: 0.9542 - val_loss: 0.0953 - val_accuracy: 0.9672
#
# Epoch 00051: accuracy did not improve from 0.95489
# Epoch 52/200
# 214778/214778 [==============================] - 8s 37us/step - loss: 0.1210 - accuracy: 0.9544 - val_loss: 0.0996 - val_accuracy: 0.9656
#
# Epoch 00052: accuracy did not improve from 0.95489
# Epoch 53/200
# 214778/214778 [==============================] - 10s 47us/step - loss: 0.1220 - accuracy: 0.9543 - val_loss: 0.0992 - val_accuracy: 0.9667
#
# Epoch 00053: accuracy did not improve from 0.95489
# Epoch 54/200
# 214778/214778 [==============================] - 12s 54us/step - loss: 0.1218 - accuracy: 0.9543 - val_loss: 0.0975 - val_accuracy: 0.9667
#
# Epoch 00054: accuracy did not improve from 0.95489
# Epoch 55/200
# 214778/214778 [==============================] - 11s 51us/step - loss: 0.1209 - accuracy: 0.9548 - val_loss: 0.0955 - val_accuracy: 0.9664
#
# Epoch 00055: accuracy did not improve from 0.95489
# Epoch 56/200
# 214778/214778 [==============================] - 11s 50us/step - loss: 0.1202 - accuracy: 0.9554 - val_loss: 0.1024 - val_accuracy: 0.9631
#
# Epoch 00056: accuracy improved from 0.95489 to 0.95536, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00056-Val_acc-0.95536_weights.hdf5
# Epoch 57/200
# 214778/214778 [==============================] - 11s 50us/step - loss: 0.1204 - accuracy: 0.9546 - val_loss: 0.0970 - val_accuracy: 0.9670
#
# Epoch 00057: accuracy did not improve from 0.95536
# Epoch 58/200
# 214778/214778 [==============================] - 12s 57us/step - loss: 0.1206 - accuracy: 0.9548 - val_loss: 0.0987 - val_accuracy: 0.9656
#
# Epoch 00058: accuracy did not improve from 0.95536
# Epoch 59/200
# 214778/214778 [==============================] - 13s 59us/step - loss: 0.1196 - accuracy: 0.9555 - val_loss: 0.0936 - val_accuracy: 0.9676
#
# Epoch 00059: accuracy improved from 0.95536 to 0.95550, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00059-Val_acc-0.95550_weights.hdf5
# Epoch 60/200
# 214778/214778 [==============================] - 11s 52us/step - loss: 0.1190 - accuracy: 0.9554 - val_loss: 0.0962 - val_accuracy: 0.9666
#
# Epoch 00060: accuracy did not improve from 0.95550
# Epoch 61/200
# 214778/214778 [==============================] - 12s 58us/step - loss: 0.1193 - accuracy: 0.9555 - val_loss: 0.0990 - val_accuracy: 0.9666
#
# Epoch 00061: accuracy did not improve from 0.95550
# Epoch 62/200
# 214778/214778 [==============================] - 14s 66us/step - loss: 0.1199 - accuracy: 0.9552 - val_loss: 0.0947 - val_accuracy: 0.9676
#
# Epoch 00062: accuracy did not improve from 0.95550
# Epoch 63/200
# 214778/214778 [==============================] - 13s 59us/step - loss: 0.1185 - accuracy: 0.9555 - val_loss: 0.0973 - val_accuracy: 0.9662
#
# Epoch 00063: accuracy did not improve from 0.95550
# Epoch 64/200
# 214778/214778 [==============================] - 11s 49us/step - loss: 0.1181 - accuracy: 0.9557 - val_loss: 0.0974 - val_accuracy: 0.9658
#
# Epoch 00064: accuracy improved from 0.95550 to 0.95570, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00064-Val_acc-0.95570_weights.hdf5
# Epoch 65/200
# 214778/214778 [==============================] - 10s 46us/step - loss: 0.1187 - accuracy: 0.9556 - val_loss: 0.0987 - val_accuracy: 0.9651
#
# Epoch 00065: accuracy did not improve from 0.95570
# Epoch 66/200
# 214778/214778 [==============================] - 10s 46us/step - loss: 0.1196 - accuracy: 0.9548 - val_loss: 0.0938 - val_accuracy: 0.9692
#
# Epoch 00066: accuracy did not improve from 0.95570
# Epoch 67/200
# 214778/214778 [==============================] - 11s 52us/step - loss: 0.1177 - accuracy: 0.9564 - val_loss: 0.0971 - val_accuracy: 0.9666
#
# Epoch 00067: accuracy improved from 0.95570 to 0.95636, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00067-Val_acc-0.95636_weights.hdf5
# Epoch 68/200
# 214778/214778 [==============================] - 11s 50us/step - loss: 0.1176 - accuracy: 0.9561 - val_loss: 0.0934 - val_accuracy: 0.9672
#
# Epoch 00068: accuracy did not improve from 0.95636
# Epoch 69/200
# 214778/214778 [==============================] - 10s 48us/step - loss: 0.1175 - accuracy: 0.9563 - val_loss: 0.0942 - val_accuracy: 0.9692
#
# Epoch 00069: accuracy did not improve from 0.95636
# Epoch 70/200
# 214778/214778 [==============================] - 10s 49us/step - loss: 0.1184 - accuracy: 0.9557 - val_loss: 0.0932 - val_accuracy: 0.9675
#
# Epoch 00070: accuracy did not improve from 0.95636
# Epoch 71/200
# 214778/214778 [==============================] - 10s 47us/step - loss: 0.1166 - accuracy: 0.9568 - val_loss: 0.0912 - val_accuracy: 0.9689
#
# Epoch 00071: accuracy improved from 0.95636 to 0.95678, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00071-Val_acc-0.95678_weights.hdf5
# Epoch 72/200
# 214778/214778 [==============================] - 11s 49us/step - loss: 0.1170 - accuracy: 0.9566 - val_loss: 0.0958 - val_accuracy: 0.9664
#
# Epoch 00072: accuracy did not improve from 0.95678
# Epoch 73/200
# 214778/214778 [==============================] - 10s 48us/step - loss: 0.1174 - accuracy: 0.9561 - val_loss: 0.0936 - val_accuracy: 0.9682
#
# Epoch 00073: accuracy did not improve from 0.95678
# Epoch 74/200
# 214778/214778 [==============================] - 10s 47us/step - loss: 0.1162 - accuracy: 0.9568 - val_loss: 0.0888 - val_accuracy: 0.9699
#
# Epoch 00074: accuracy improved from 0.95678 to 0.95680, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00074-Val_acc-0.95680_weights.hdf5
# Epoch 75/200
# 214778/214778 [==============================] - 10s 45us/step - loss: 0.1160 - accuracy: 0.9570 - val_loss: 0.0952 - val_accuracy: 0.9678
#
# Epoch 00075: accuracy improved from 0.95680 to 0.95698, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00075-Val_acc-0.95698_weights.hdf5
# Epoch 76/200
# 214778/214778 [==============================] - 9s 40us/step - loss: 0.1169 - accuracy: 0.9567 - val_loss: 0.0876 - val_accuracy: 0.9705
#
# Epoch 00076: accuracy did not improve from 0.95698
# Epoch 77/200
# 214778/214778 [==============================] - 10s 48us/step - loss: 0.1167 - accuracy: 0.9561 - val_loss: 0.0955 - val_accuracy: 0.9654
#
# Epoch 00077: accuracy did not improve from 0.95698
# Epoch 78/200
# 214778/214778 [==============================] - 9s 42us/step - loss: 0.1151 - accuracy: 0.9574 - val_loss: 0.0952 - val_accuracy: 0.9662
#
# Epoch 00078: accuracy improved from 0.95698 to 0.95736, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00078-Val_acc-0.95736_weights.hdf5
# Epoch 79/200
# 214778/214778 [==============================] - 14s 64us/step - loss: 0.1158 - accuracy: 0.9567 - val_loss: 0.0922 - val_accuracy: 0.9691
#
# Epoch 00079: accuracy did not improve from 0.95736
# Epoch 80/200
# 214778/214778 [==============================] - 7s 33us/step - loss: 0.1159 - accuracy: 0.9565 - val_loss: 0.0973 - val_accuracy: 0.9664
#
# Epoch 00080: accuracy did not improve from 0.95736
# Epoch 81/200
# 214778/214778 [==============================] - 10s 49us/step - loss: 0.1154 - accuracy: 0.9573 - val_loss: 0.0893 - val_accuracy: 0.9705
#
# Epoch 00081: accuracy did not improve from 0.95736
# Epoch 82/200
# 214778/214778 [==============================] - 9s 44us/step - loss: 0.1157 - accuracy: 0.9569 - val_loss: 0.0931 - val_accuracy: 0.9676
#
# Epoch 00082: accuracy did not improve from 0.95736
# Epoch 83/200
# 214778/214778 [==============================] - 5s 23us/step - loss: 0.1155 - accuracy: 0.9570 - val_loss: 0.0884 - val_accuracy: 0.9695
#
# Epoch 00083: accuracy did not improve from 0.95736
# Epoch 84/200
# 214778/214778 [==============================] - 5s 21us/step - loss: 0.1148 - accuracy: 0.9571 - val_loss: 0.0941 - val_accuracy: 0.9677
#
# Epoch 00084: accuracy did not improve from 0.95736
# Epoch 85/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1135 - accuracy: 0.9575 - val_loss: 0.0890 - val_accuracy: 0.9699
#
# Epoch 00085: accuracy improved from 0.95736 to 0.95745, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00085-Val_acc-0.95745_weights.hdf5
# Epoch 86/200
# 214778/214778 [==============================] - 7s 31us/step - loss: 0.1144 - accuracy: 0.9577 - val_loss: 0.0924 - val_accuracy: 0.9687
#
# Epoch 00086: accuracy improved from 0.95745 to 0.95773, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00086-Val_acc-0.95773_weights.hdf5
# Epoch 87/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1139 - accuracy: 0.9575 - val_loss: 0.0896 - val_accuracy: 0.9686
#
# Epoch 00087: accuracy did not improve from 0.95773
# Epoch 88/200
# 214778/214778 [==============================] - 6s 26us/step - loss: 0.1147 - accuracy: 0.9573 - val_loss: 0.1037 - val_accuracy: 0.9623
#
# Epoch 00088: accuracy did not improve from 0.95773
# Epoch 89/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1140 - accuracy: 0.9575 - val_loss: 0.0875 - val_accuracy: 0.9717
#
# Epoch 00089: accuracy did not improve from 0.95773
# Epoch 90/200
# 214778/214778 [==============================] - 6s 26us/step - loss: 0.1132 - accuracy: 0.9582 - val_loss: 0.0870 - val_accuracy: 0.9718
#
# Epoch 00090: accuracy improved from 0.95773 to 0.95824, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00090-Val_acc-0.95824_weights.hdf5
# Epoch 91/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1137 - accuracy: 0.9579 - val_loss: 0.0947 - val_accuracy: 0.9667
#
# Epoch 00091: accuracy did not improve from 0.95824
# Epoch 92/200
# 214778/214778 [==============================] - 7s 31us/step - loss: 0.1124 - accuracy: 0.9582 - val_loss: 0.0916 - val_accuracy: 0.9695
#
# Epoch 00092: accuracy did not improve from 0.95824
# Epoch 93/200
# 214778/214778 [==============================] - 6s 30us/step - loss: 0.1142 - accuracy: 0.9574 - val_loss: 0.0881 - val_accuracy: 0.9704
#
# Epoch 00093: accuracy did not improve from 0.95824
# Epoch 94/200
# 214778/214778 [==============================] - 5s 22us/step - loss: 0.1129 - accuracy: 0.9581 - val_loss: 0.0943 - val_accuracy: 0.9675
#
# Epoch 00094: accuracy did not improve from 0.95824
# Epoch 95/200
# 214778/214778 [==============================] - 5s 22us/step - loss: 0.1129 - accuracy: 0.9585 - val_loss: 0.0873 - val_accuracy: 0.9697
#
# Epoch 00095: accuracy improved from 0.95824 to 0.95850, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00095-Val_acc-0.95850_weights.hdf5
# Epoch 96/200
# 214778/214778 [==============================] - 6s 30us/step - loss: 0.1112 - accuracy: 0.9585 - val_loss: 0.0869 - val_accuracy: 0.9702
#
# Epoch 00096: accuracy improved from 0.95850 to 0.95855, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00096-Val_acc-0.95855_weights.hdf5
# Epoch 97/200
# 214778/214778 [==============================] - 6s 29us/step - loss: 0.1117 - accuracy: 0.9587 - val_loss: 0.0917 - val_accuracy: 0.9676
#
# Epoch 00097: accuracy improved from 0.95855 to 0.95866, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00097-Val_acc-0.95866_weights.hdf5
# Epoch 98/200
# 214778/214778 [==============================] - 6s 28us/step - loss: 0.1127 - accuracy: 0.9582 - val_loss: 0.0941 - val_accuracy: 0.9664
#
# Epoch 00098: accuracy did not improve from 0.95866
# Epoch 99/200
# 214778/214778 [==============================] - 6s 28us/step - loss: 0.1116 - accuracy: 0.9586 - val_loss: 0.0913 - val_accuracy: 0.9665
#
# Epoch 00099: accuracy did not improve from 0.95866
# Epoch 100/200
# 214778/214778 [==============================] - 6s 29us/step - loss: 0.1120 - accuracy: 0.9583 - val_loss: 0.0863 - val_accuracy: 0.9711
#
# Epoch 00100: accuracy did not improve from 0.95866
# Epoch 101/200
# 214778/214778 [==============================] - 6s 28us/step - loss: 0.1110 - accuracy: 0.9590 - val_loss: 0.0814 - val_accuracy: 0.9743
#
# Epoch 00101: accuracy improved from 0.95866 to 0.95898, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00101-Val_acc-0.95898_weights.hdf5
# Epoch 102/200
# 214778/214778 [==============================] - 7s 31us/step - loss: 0.1119 - accuracy: 0.9587 - val_loss: 0.0862 - val_accuracy: 0.9725
#
# Epoch 00102: accuracy did not improve from 0.95898
# Epoch 103/200
# 214778/214778 [==============================] - 6s 27us/step - loss: 0.1118 - accuracy: 0.9588 - val_loss: 0.0874 - val_accuracy: 0.9713
#
# Epoch 00103: accuracy did not improve from 0.95898
# Epoch 104/200
# 214778/214778 [==============================] - 7s 32us/step - loss: 0.1118 - accuracy: 0.9587 - val_loss: 0.0846 - val_accuracy: 0.9746
#
# Epoch 00104: accuracy did not improve from 0.95898
# Epoch 105/200
# 214778/214778 [==============================] - 6s 26us/step - loss: 0.1105 - accuracy: 0.9595 - val_loss: 0.0855 - val_accuracy: 0.9723
#
# Epoch 00105: accuracy improved from 0.95898 to 0.95949, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00105-Val_acc-0.95949_weights.hdf5
# Epoch 106/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1103 - accuracy: 0.9594 - val_loss: 0.0934 - val_accuracy: 0.9672
#
# Epoch 00106: accuracy did not improve from 0.95949
# Epoch 107/200
# 214778/214778 [==============================] - 5s 22us/step - loss: 0.1106 - accuracy: 0.9593 - val_loss: 0.0863 - val_accuracy: 0.9705
#
# Epoch 00107: accuracy did not improve from 0.95949
# Epoch 108/200
# 214778/214778 [==============================] - 5s 21us/step - loss: 0.1107 - accuracy: 0.9591 - val_loss: 0.0897 - val_accuracy: 0.9684
#
# Epoch 00108: accuracy did not improve from 0.95949
# Epoch 109/200
# 214778/214778 [==============================] - 9s 41us/step - loss: 0.1100 - accuracy: 0.9597 - val_loss: 0.0843 - val_accuracy: 0.9725
#
# Epoch 00109: accuracy improved from 0.95949 to 0.95966, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00109-Val_acc-0.95966_weights.hdf5
# Epoch 110/200
# 214778/214778 [==============================] - 7s 32us/step - loss: 0.1076 - accuracy: 0.9606 - val_loss: 0.0827 - val_accuracy: 0.9733
#
# Epoch 00110: accuracy improved from 0.95966 to 0.96061, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00110-Val_acc-0.96061_weights.hdf5
# Epoch 111/200
# 214778/214778 [==============================] - 8s 36us/step - loss: 0.1114 - accuracy: 0.9588 - val_loss: 0.0817 - val_accuracy: 0.9744
#
# Epoch 00111: accuracy did not improve from 0.96061
# Epoch 112/200
# 214778/214778 [==============================] - 7s 31us/step - loss: 0.1095 - accuracy: 0.9603 - val_loss: 0.0881 - val_accuracy: 0.9735
#
# Epoch 00112: accuracy did not improve from 0.96061
# Epoch 113/200
# 214778/214778 [==============================] - 7s 32us/step - loss: 0.1100 - accuracy: 0.9598 - val_loss: 0.0843 - val_accuracy: 0.9737
#
# Epoch 00113: accuracy did not improve from 0.96061
# Epoch 114/200
# 214778/214778 [==============================] - 7s 31us/step - loss: 0.1079 - accuracy: 0.9607 - val_loss: 0.0884 - val_accuracy: 0.9713
#
# Epoch 00114: accuracy improved from 0.96061 to 0.96068, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00114-Val_acc-0.96068_weights.hdf5
# Epoch 115/200
# 214778/214778 [==============================] - 8s 35us/step - loss: 0.1096 - accuracy: 0.9598 - val_loss: 0.0868 - val_accuracy: 0.9693
#
# Epoch 00115: accuracy did not improve from 0.96068
# Epoch 116/200
# 214778/214778 [==============================] - 9s 41us/step - loss: 0.1088 - accuracy: 0.9604 - val_loss: 0.0879 - val_accuracy: 0.9683
#
# Epoch 00116: accuracy did not improve from 0.96068
# Epoch 117/200
# 214778/214778 [==============================] - 7s 32us/step - loss: 0.1090 - accuracy: 0.9600 - val_loss: 0.0874 - val_accuracy: 0.9701
#
# Epoch 00117: accuracy did not improve from 0.96068
# Epoch 118/200
# 214778/214778 [==============================] - 6s 26us/step - loss: 0.1097 - accuracy: 0.9601 - val_loss: 0.0895 - val_accuracy: 0.9690
#
# Epoch 00118: accuracy did not improve from 0.96068
# Epoch 119/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1090 - accuracy: 0.9599 - val_loss: 0.0887 - val_accuracy: 0.9687
#
# Epoch 00119: accuracy did not improve from 0.96068
# Epoch 120/200
# 214778/214778 [==============================] - 7s 32us/step - loss: 0.1095 - accuracy: 0.9601 - val_loss: 0.0795 - val_accuracy: 0.9746
#
# Epoch 00120: accuracy did not improve from 0.96068
# Epoch 121/200
# 214778/214778 [==============================] - 6s 30us/step - loss: 0.1078 - accuracy: 0.9605 - val_loss: 0.0798 - val_accuracy: 0.9741
#
# Epoch 00121: accuracy did not improve from 0.96068
# Epoch 122/200
# 214778/214778 [==============================] - 9s 40us/step - loss: 0.1081 - accuracy: 0.9605 - val_loss: 0.0835 - val_accuracy: 0.9744
#
# Epoch 00122: accuracy did not improve from 0.96068
# Epoch 123/200
# 214778/214778 [==============================] - 7s 31us/step - loss: 0.1083 - accuracy: 0.9605 - val_loss: 0.0822 - val_accuracy: 0.9734
#
# Epoch 00123: accuracy did not improve from 0.96068
# Epoch 124/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1067 - accuracy: 0.9614 - val_loss: 0.0832 - val_accuracy: 0.9725
#
# Epoch 00124: accuracy improved from 0.96068 to 0.96135, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00124-Val_acc-0.96135_weights.hdf5
# Epoch 125/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1080 - accuracy: 0.9606 - val_loss: 0.0816 - val_accuracy: 0.9737
#
# Epoch 00125: accuracy did not improve from 0.96135
# Epoch 126/200
# 214778/214778 [==============================] - 8s 36us/step - loss: 0.1074 - accuracy: 0.9607 - val_loss: 0.0920 - val_accuracy: 0.9681
#
# Epoch 00126: accuracy did not improve from 0.96135
# Epoch 127/200
# 214778/214778 [==============================] - 6s 26us/step - loss: 0.1075 - accuracy: 0.9610 - val_loss: 0.0848 - val_accuracy: 0.9719
# Epoch 00127: accuracy did not improve from 0.96135
# Epoch 128/200
# 214778/214778 [==============================] - 6s 26us/step - loss: 0.1061 - accuracy: 0.9613 - val_loss: 0.0871 - val_accuracy: 0.9695
#
# Epoch 00128: accuracy did not improve from 0.96135
# Epoch 129/200
# 214778/214778 [==============================] - 6s 27us/step - loss: 0.1070 - accuracy: 0.9613 - val_loss: 0.0806 - val_accuracy: 0.9748
#
# Epoch 00129: accuracy did not improve from 0.96135
# Epoch 130/200
# 214778/214778 [==============================] - 6s 27us/step - loss: 0.1079 - accuracy: 0.9610 - val_loss: 0.0820 - val_accuracy: 0.9729
#
# Epoch 00130: accuracy did not improve from 0.96135
# Epoch 131/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1079 - accuracy: 0.9610 - val_loss: 0.0877 - val_accuracy: 0.9717
#
# Epoch 00131: accuracy did not improve from 0.96135
# Epoch 132/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1069 - accuracy: 0.9612 - val_loss: 0.0854 - val_accuracy: 0.9729
#
# Epoch 00132: accuracy did not improve from 0.96135
# Epoch 133/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1066 - accuracy: 0.9615 - val_loss: 0.0854 - val_accuracy: 0.9706
#
# Epoch 00133: accuracy improved from 0.96135 to 0.96155, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00133-Val_acc-0.96155_weights.hdf5
# Epoch 134/200
# 214778/214778 [==============================] - 6s 28us/step - loss: 0.1065 - accuracy: 0.9615 - val_loss: 0.0989 - val_accuracy: 0.9644
#
# Epoch 00134: accuracy did not improve from 0.96155
# Epoch 135/200
# 214778/214778 [==============================] - 6s 28us/step - loss: 0.1072 - accuracy: 0.9614 - val_loss: 0.0795 - val_accuracy: 0.9751
#
# Epoch 00135: accuracy did not improve from 0.96155
# Epoch 136/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1056 - accuracy: 0.9621 - val_loss: 0.0797 - val_accuracy: 0.9737
#
# Epoch 00136: accuracy improved from 0.96155 to 0.96206, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00136-Val_acc-0.96206_weights.hdf5
# Epoch 137/200
# 214778/214778 [==============================] - 5s 23us/step - loss: 0.1062 - accuracy: 0.9618 - val_loss: 0.0833 - val_accuracy: 0.9743
#
# Epoch 00137: accuracy did not improve from 0.96206
# Epoch 138/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1063 - accuracy: 0.9618 - val_loss: 0.0833 - val_accuracy: 0.9731
#
# Epoch 00138: accuracy did not improve from 0.96206
# Epoch 139/200
# 214778/214778 [==============================] - 6s 26us/step - loss: 0.1080 - accuracy: 0.9609 - val_loss: 0.0860 - val_accuracy: 0.9706
#
# Epoch 00139: accuracy did not improve from 0.96206
# Epoch 140/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1059 - accuracy: 0.9617 - val_loss: 0.0811 - val_accuracy: 0.9741
#
# Epoch 00140: accuracy did not improve from 0.96206
# Epoch 141/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1073 - accuracy: 0.9612 - val_loss: 0.0862 - val_accuracy: 0.9692
#
# Epoch 00141: accuracy did not improve from 0.96206
# Epoch 142/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1059 - accuracy: 0.9621 - val_loss: 0.0797 - val_accuracy: 0.9749
#
# Epoch 00142: accuracy improved from 0.96206 to 0.96208, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00142-Val_acc-0.96208_weights.hdf5
# Epoch 143/200
# 214778/214778 [==============================] - 8s 36us/step - loss: 0.1073 - accuracy: 0.9610 - val_loss: 0.0819 - val_accuracy: 0.9730
#
# Epoch 00143: accuracy did not improve from 0.96208
# Epoch 144/200
# 214778/214778 [==============================] - 6s 27us/step - loss: 0.1059 - accuracy: 0.9617 - val_loss: 0.0796 - val_accuracy: 0.9743
#
# Epoch 00144: accuracy did not improve from 0.96208
# Epoch 145/200
# 214778/214778 [==============================] - 7s 32us/step - loss: 0.1057 - accuracy: 0.9617 - val_loss: 0.0773 - val_accuracy: 0.9759
#
# Epoch 00145: accuracy did not improve from 0.96208
# Epoch 146/200
# 214778/214778 [==============================] - 9s 40us/step - loss: 0.1057 - accuracy: 0.9621 - val_loss: 0.0763 - val_accuracy: 0.9766
#
# Epoch 00146: accuracy did not improve from 0.96208
# Epoch 147/200
# 214778/214778 [==============================] - 6s 28us/step - loss: 0.1058 - accuracy: 0.9619 - val_loss: 0.0833 - val_accuracy: 0.9727
#
# Epoch 00147: accuracy did not improve from 0.96208
# Epoch 148/200
# 214778/214778 [==============================] - 6s 27us/step - loss: 0.1047 - accuracy: 0.9629 - val_loss: 0.0838 - val_accuracy: 0.9743
#
# Epoch 00148: accuracy improved from 0.96208 to 0.96288, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00148-Val_acc-0.96288_weights.hdf5
# Epoch 149/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1051 - accuracy: 0.9623 - val_loss: 0.0762 - val_accuracy: 0.9767
#
# Epoch 00149: accuracy did not improve from 0.96288
# Epoch 150/200
# 214778/214778 [==============================] - 6s 30us/step - loss: 0.1054 - accuracy: 0.9626 - val_loss: 0.0787 - val_accuracy: 0.9767
#
# Epoch 00150: accuracy did not improve from 0.96288
# Epoch 151/200
# 214778/214778 [==============================] - 5s 22us/step - loss: 0.1045 - accuracy: 0.9626 - val_loss: 0.0803 - val_accuracy: 0.9749
#
# Epoch 00151: accuracy did not improve from 0.96288
# Epoch 152/200
# 214778/214778 [==============================] - 7s 31us/step - loss: 0.1048 - accuracy: 0.9623 - val_loss: 0.0811 - val_accuracy: 0.9749
#
# Epoch 00152: accuracy did not improve from 0.96288
# Epoch 153/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1046 - accuracy: 0.9626 - val_loss: 0.0761 - val_accuracy: 0.9770
#
# Epoch 00153: accuracy did not improve from 0.96288
# Epoch 154/200
# 214778/214778 [==============================] - 7s 33us/step - loss: 0.1043 - accuracy: 0.9629 - val_loss: 0.0766 - val_accuracy: 0.9757
#
# Epoch 00154: accuracy improved from 0.96288 to 0.96290, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00154-Val_acc-0.96290_weights.hdf5
# Epoch 155/200
# 214778/214778 [==============================] - 9s 42us/step - loss: 0.1053 - accuracy: 0.9620 - val_loss: 0.0791 - val_accuracy: 0.9747
#
# Epoch 00155: accuracy did not improve from 0.96290
# Epoch 156/200
# 214778/214778 [==============================] - 5s 22us/step - loss: 0.1060 - accuracy: 0.9621 - val_loss: 0.0794 - val_accuracy: 0.9747
#
# Epoch 00156: accuracy did not improve from 0.96290
# Epoch 157/200
# 214778/214778 [==============================] - 4s 21us/step - loss: 0.1052 - accuracy: 0.9625 - val_loss: 0.0778 - val_accuracy: 0.9754
#
# Epoch 00157: accuracy did not improve from 0.96290
# Epoch 158/200
# 214778/214778 [==============================] - 5s 22us/step - loss: 0.1056 - accuracy: 0.9622 - val_loss: 0.0842 - val_accuracy: 0.9717
#
# Epoch 00158: accuracy did not improve from 0.96290
# Epoch 159/200
# 214778/214778 [==============================] - 6s 30us/step - loss: 0.1051 - accuracy: 0.9625 - val_loss: 0.0787 - val_accuracy: 0.9736
#
# Epoch 00159: accuracy did not improve from 0.96290
# Epoch 160/200
# 214778/214778 [==============================] - 6s 26us/step - loss: 0.1034 - accuracy: 0.9632 - val_loss: 0.0785 - val_accuracy: 0.9756
#
# Epoch 00160: accuracy improved from 0.96290 to 0.96322, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00160-Val_acc-0.96322_weights.hdf5
# Epoch 161/200
# 214778/214778 [==============================] - 9s 43us/step - loss: 0.1041 - accuracy: 0.9632 - val_loss: 0.0779 - val_accuracy: 0.9756
#
# Epoch 00161: accuracy did not improve from 0.96322
# Epoch 162/200
# 214778/214778 [==============================] - 5s 23us/step - loss: 0.1043 - accuracy: 0.9629 - val_loss: 0.0845 - val_accuracy: 0.9707
#
# Epoch 00162: accuracy did not improve from 0.96322
# Epoch 163/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1051 - accuracy: 0.9623 - val_loss: 0.0811 - val_accuracy: 0.9747
#
# Epoch 00163: accuracy did not improve from 0.96322
# Epoch 164/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1054 - accuracy: 0.9623 - val_loss: 0.0793 - val_accuracy: 0.9758
#
# Epoch 00164: accuracy did not improve from 0.96322
# Epoch 165/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1041 - accuracy: 0.9629 - val_loss: 0.0805 - val_accuracy: 0.9742
#
# Epoch 00165: accuracy did not improve from 0.96322
# Epoch 166/200
# 214778/214778 [==============================] - 5s 22us/step - loss: 0.1039 - accuracy: 0.9629 - val_loss: 0.0773 - val_accuracy: 0.9770
#
# Epoch 00166: accuracy did not improve from 0.96322
# Epoch 167/200
# 214778/214778 [==============================] - 5s 23us/step - loss: 0.1040 - accuracy: 0.9630 - val_loss: 0.0821 - val_accuracy: 0.9716
#
# Epoch 00167: accuracy did not improve from 0.96322
# Epoch 168/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1039 - accuracy: 0.9629 - val_loss: 0.0794 - val_accuracy: 0.9747
#
# Epoch 00168: accuracy did not improve from 0.96322
# Epoch 169/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1051 - accuracy: 0.9625 - val_loss: 0.0777 - val_accuracy: 0.9768
#
# Epoch 00169: accuracy did not improve from 0.96322
# Epoch 170/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1042 - accuracy: 0.9629 - val_loss: 0.0764 - val_accuracy: 0.9777
#
# Epoch 00170: accuracy did not improve from 0.96322
# Epoch 171/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1039 - accuracy: 0.9630 - val_loss: 0.0775 - val_accuracy: 0.9750
#
# Epoch 00171: accuracy did not improve from 0.96322
# Epoch 172/200
# 214778/214778 [==============================] - 5s 23us/step - loss: 0.1035 - accuracy: 0.9630 - val_loss: 0.0781 - val_accuracy: 0.9768
#
# Epoch 00172: accuracy did not improve from 0.96322
# Epoch 173/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1033 - accuracy: 0.9630 - val_loss: 0.0741 - val_accuracy: 0.9774
#
# Epoch 00173: accuracy did not improve from 0.96322
# Epoch 174/200
# 214778/214778 [==============================] - 5s 23us/step - loss: 0.1042 - accuracy: 0.9627 - val_loss: 0.0774 - val_accuracy: 0.9762
#
# Epoch 00174: accuracy did not improve from 0.96322
# Epoch 175/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1031 - accuracy: 0.9631 - val_loss: 0.0781 - val_accuracy: 0.9761
#
# Epoch 00175: accuracy did not improve from 0.96322
# Epoch 176/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1041 - accuracy: 0.9627 - val_loss: 0.0786 - val_accuracy: 0.9751
#
# Epoch 00176: accuracy did not improve from 0.96322
# Epoch 177/200
# 214778/214778 [==============================] - 5s 23us/step - loss: 0.1030 - accuracy: 0.9631 - val_loss: 0.0814 - val_accuracy: 0.9731
#
# Epoch 00177: accuracy did not improve from 0.96322
# Epoch 178/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1038 - accuracy: 0.9627 - val_loss: 0.0782 - val_accuracy: 0.9766
#
# Epoch 00178: accuracy did not improve from 0.96322
# Epoch 179/200
# 214778/214778 [==============================] - 5s 23us/step - loss: 0.1038 - accuracy: 0.9629 - val_loss: 0.0786 - val_accuracy: 0.9743
#
# Epoch 00179: accuracy did not improve from 0.96322
# Epoch 180/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1036 - accuracy: 0.9632 - val_loss: 0.0753 - val_accuracy: 0.9773
#
# Epoch 00180: accuracy did not improve from 0.96322
# Epoch 181/200
# 214778/214778 [==============================] - 6s 27us/step - loss: 0.1036 - accuracy: 0.9630 - val_loss: 0.0781 - val_accuracy: 0.9762
#
# Epoch 00181: accuracy did not improve from 0.96322
# Epoch 182/200
# 214778/214778 [==============================] - 6s 28us/step - loss: 0.1035 - accuracy: 0.9634 - val_loss: 0.0766 - val_accuracy: 0.9766
#
# Epoch 00182: accuracy improved from 0.96322 to 0.96336, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00182-Val_acc-0.96336_weights.hdf5
# Epoch 183/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1051 - accuracy: 0.9621 - val_loss: 0.0758 - val_accuracy: 0.9767
#
# Epoch 00183: accuracy did not improve from 0.96336
# Epoch 184/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1027 - accuracy: 0.9636 - val_loss: 0.0846 - val_accuracy: 0.9714
#
# Epoch 00184: accuracy improved from 0.96336 to 0.96359, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00184-Val_acc-0.96359_weights.hdf5
# Epoch 185/200
# 214778/214778 [==============================] - 5s 22us/step - loss: 0.1034 - accuracy: 0.9635 - val_loss: 0.0808 - val_accuracy: 0.9734
#
# Epoch 00185: accuracy did not improve from 0.96359
# Epoch 186/200
# 214778/214778 [==============================] - 5s 21us/step - loss: 0.1031 - accuracy: 0.9633 - val_loss: 0.0824 - val_accuracy: 0.9749
#
# Epoch 00186: accuracy did not improve from 0.96359
# Epoch 187/200
# 214778/214778 [==============================] - 6s 30us/step - loss: 0.1030 - accuracy: 0.9633 - val_loss: 0.0755 - val_accuracy: 0.9769
#
# Epoch 00187: accuracy did not improve from 0.96359
# Epoch 188/200
# 214778/214778 [==============================] - 8s 36us/step - loss: 0.1037 - accuracy: 0.9631 - val_loss: 0.0802 - val_accuracy: 0.9749
#
# Epoch 00188: accuracy did not improve from 0.96359
# Epoch 189/200
# 214778/214778 [==============================] - 6s 29us/step - loss: 0.1026 - accuracy: 0.9635 - val_loss: 0.0755 - val_accuracy: 0.9759
#
# Epoch 00189: accuracy did not improve from 0.96359
# Epoch 190/200
# 214778/214778 [==============================] - 5s 21us/step - loss: 0.1025 - accuracy: 0.9637 - val_loss: 0.0755 - val_accuracy: 0.9773
#
# Epoch 00190: accuracy improved from 0.96359 to 0.96369, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00190-Val_acc-0.96369_weights.hdf5
# Epoch 191/200
# 214778/214778 [==============================] - 5s 23us/step - loss: 0.1029 - accuracy: 0.9636 - val_loss: 0.0798 - val_accuracy: 0.9738
#
# Epoch 00191: accuracy did not improve from 0.96369
# Epoch 192/200
# 214778/214778 [==============================] - 7s 31us/step - loss: 0.1025 - accuracy: 0.9635 - val_loss: 0.0787 - val_accuracy: 0.9755
#
# Epoch 00192: accuracy did not improve from 0.96369
# Epoch 193/200
# 214778/214778 [==============================] - 6s 30us/step - loss: 0.1027 - accuracy: 0.9636 - val_loss: 0.0789 - val_accuracy: 0.9753
#
# Epoch 00193: accuracy did not improve from 0.96369
# Epoch 194/200
# 214778/214778 [==============================] - 5s 21us/step - loss: 0.1034 - accuracy: 0.9630 - val_loss: 0.0840 - val_accuracy: 0.9716
#
# Epoch 00194: accuracy did not improve from 0.96369
# Epoch 195/200
# 214778/214778 [==============================] - 5s 24us/step - loss: 0.1022 - accuracy: 0.9635 - val_loss: 0.0758 - val_accuracy: 0.9775
#
# Epoch 00195: accuracy did not improve from 0.96369
# Epoch 196/200
# 214778/214778 [==============================] - 8s 38us/step - loss: 0.1039 - accuracy: 0.9630 - val_loss: 0.0754 - val_accuracy: 0.9771
#
# Epoch 00196: accuracy did not improve from 0.96369
# Epoch 197/200
# 214778/214778 [==============================] - 5s 25us/step - loss: 0.1036 - accuracy: 0.9632 - val_loss: 0.0744 - val_accuracy: 0.9776
#
# Epoch 00197: accuracy did not improve from 0.96369
# Epoch 198/200
# 214778/214778 [==============================] - 5s 23us/step - loss: 0.1026 - accuracy: 0.9641 - val_loss: 0.0809 - val_accuracy: 0.9711
#
# Epoch 00198: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00198: accuracy improved from 0.96369 to 0.96413, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00198-Val_acc-0.96413_weights.hdf5
# Epoch 199/200
# 214778/214778 [==============================] - 8s 37us/step - loss: 0.0968 - accuracy: 0.9669 - val_loss: 0.0731 - val_accuracy: 0.9779
#
# Epoch 00199: accuracy improved from 0.96413 to 0.96688, saving model to ../../data/bfalg_models/bfalg_batchSize_200_Epoch-00199-Val_acc-0.96688_weights.hdf5
# Epoch 200/200
# 214778/214778 [==============================] - 6s 30us/step - loss: 0.0973 - accuracy: 0.9664 - val_loss: 0.0738 - val_accuracy: 0.9780
#
# Epoch 00200: accuracy did not improve from 0.96688
# 30377/30377 [==============================] - 0s 7us/step
#
# Test loss: 0.0725%
# Test accuracy: 97.8141%
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy', 'lr'])

# %%
# List all data in history
print(history.history.keys())

# Summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'validate'], loc='upper left')
plt.draw()
plt.show()
plt.pause(1)    

# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validate'], loc='upper left')
plt.draw()
plt.show()
plt.pause(1)
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy', 'lr'])

# %%
y_pred = model.predict(X_test)

# %%
sns.kdeplot(y_pred.flatten(),cut=0);
thresh = filters.threshold_otsu(y_pred)
plt.axvline(thresh, color='k', ls='--');
plt.draw()
plt.show()

# %%
print('Otsu Threshold:', thresh)
print('Precision Score:', precision_score(y_test, y_pred>thresh))
print('Recall Score:', recall_score(y_test, y_pred > thresh))
print('F1-Score:', f1_score(y_test, y_pred > thresh))
# Out:
# Otsu Threshold: 0.49504822
# Precision Score: 0.9772154671924635
# Recall Score: 0.9863452927193322
# F1-Score: 0.981759154813327

# %% [markdown]
# ## visualize model

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')

from ann_visualizer.visualize import ann_viz;
import numpy


ann_viz(model, title="Artificial Neural network - Model Visualization")
# Out:
# Fontconfig error: "/home/chris/.config/fontconfig/fonts.conf", line 10: Extra content at the end of the document
#
# Fontconfig error: "/home/chris/.config/fontconfig/fonts.conf", line 10: Extra content at the end of the document
#
# Fontconfig error: "/home/chris/.config/fontconfig/fonts.conf", line 10: Extra content at the end of the document
#
# Fontconfig error: "/home/chris/.config/fontconfig/fonts.conf", line 10: Extra content at the end of the document
#
# Fontconfig error: "/home/chris/.config/fontconfig/fonts.conf", line 10: Extra content at the end of the document

# %% [markdown]
# # Do inference

# %%
# load model
from keras.models import load_model


path = '../../data/bfalg_models/bfalg_batchSize_200_Epoch-00049-Val_acc-0.93902_weights.hdf5'
model = load_model(path)

# %%
from skimage import exposure
from skimage.filters import threshold_otsu, threshold_local
import matplotlib.pyplot as plt
from pprint import pprint
import pandas as pd

from gbdxtools import Interface
gbdx = Interface()

# %%
def rgb_from_raster(data, brightness):
    
    bands, x, y = data.shape
    
    # create plottable image
    brightness = 0.3
    blue = data[1].astype(np.float32)
    green = data[2].astype(np.float32)
    red = data[4].astype(np.float32)
    rgb = np.zeros((x,y,3))
    rgb[...,0] = red
    rgb[...,1] = green
    rgb[...,2] = blue
    rgb = rgb - np.min(rgb)
    rgb = rgb / np.maximum(np.max(rgb), 1) + brightness
    
    if rgb.mean() > 1:
        rgb[rgb > 255] = 255
    else: 
        rgb[rgb > 1] = 1
    
    return rgb

# Create function that reshapes numpy arrays
def reshape(index):
    index = np.reshape(index,[1,index.shape[0],index.shape[1]])
    return(index)

# %% [markdown]
# ## Use raster file
#
# Start here when using imagery downloaded from s3
#
# Find data in following bucket: https://s3.console.aws.amazon.com/s3/buckets/gcw-rimbunio-common-input-data-dev/input_data/imagery/

# %%
# find files in imagery folder

name = ''
save_classification = True

raster_files_path = '../../data/rasters_waterbodies_osm/cities/**/{}*.tif'.format(name)
raster_files = glob.glob(raster_files_path)
file_path = raster_files[0]

print(len(raster_files))
print('-------------------------------------')
pprint(raster_files[0:5])
print('-------------------------------------')
print(file_path)
# Out:
# 520
# -------------------------------------
# ['../../data/rasters_waterbodies_osm/cities/Denpasar/Denpasar_052_pansharpen_True_2019-08-01_02:45_1030010096902A00.tif',
#  '../../data/rasters_waterbodies_osm/cities/Denpasar/Denpasar_033_pansharpen_True_2019-08-12_02:39_1030010097468D00.tif',
#  '../../data/rasters_waterbodies_osm/cities/Denpasar/Denpasar_041_pansharpen_True_2019-08-01_02:45_1030010096902A00.tif',
#  '../../data/rasters_waterbodies_osm/cities/Denpasar/Denpasar_048_pansharpen_True_2019-08-12_02:39_1030010097468D00.tif',
#  '../../data/rasters_waterbodies_osm/cities/Denpasar/Denpasar_023_pansharpen_True_2019-08-12_02:39_1030010097468D00.tif']
# -------------------------------------
# ../../data/rasters_waterbodies_osm/cities/Denpasar/Denpasar_052_pansharpen_True_2019-08-01_02:45_1030010096902A00.tif

# %%
if len(raster_files) == 1:
    sample_size = 1
else:
    sample_size = 3

# %%
for file_path in np.array(pd.DataFrame(raster_files).sample(sample_size)).flatten(): 
    
    print(file_path)
    filename = file_path.split('/')[-1]

    import rasterio

    data = rasterio.open(file_path).read()
    dataset = rasterio.open(file_path)

    transform = dataset.meta['transform']
    width = dataset.meta['width']
    height = dataset.meta['height']

    # Split image data into band layers
    coastal = data[0] 
    blue    = data[1]
    green   = data[2]
    yellow  = data[3]
    red     = data[4] 
    red_edge = data[5] 
    nir1 = data[6]
    nir2 = data[7]
    
    # get info from filenames
    stringlist = file_path.split('/')[-1].split('_')
    image_id = stringlist[-1].split('.')[0]

    # get metadata from GBDX
    record = gbdx.catalog.get(image_id)

    # add metadata to data 
    i = 8
    for property_name in property_names:

            try: 
                property_record = record['properties'][property_name]  

                property_array = np.empty([1,data.shape[1],data.shape[2]])
                property_array.fill(property_record)

                data = np.vstack([data,property_array])
            except: 
                print('failed ', property_name, image_id)
                property_array = np.empty([1,data.shape[1],data.shape[2]])
                data = np.vstack([data,property_array])

            i = i + 1


    # Calculate indices
    # Make sure ndvi and ndwi are stackable with band data by making them 3-dimensional (1,x,y)
    ndvi = reshape((nir1 - red)/(nir1 + red))
    ndwi = reshape((green - nir1) / (green + nir1))
    wwi = reshape((coastal - nir2) / (coastal + nir2 + 10e-5))

    # Stack arrays in sequence vertically (row wise)
    image_array = np.vstack([data,ndvi,ndwi, wwi])
    # select all variables of interest
    image_array = image_array[variable_selection,:,:]

    ### Reshape the data prior to feeding it through the model.
    # Flatten the two-dimensional imagery (i.e., Reshape)
    d2, h2, w2 = image_array.shape
    data_pred = np.reshape(image_array,(d2,h2*w2)).T

    # Convert data type to 32-bit float, and normalize between 0 and 1
    data_pred.astype(np.float32)
    data_pred = (data_pred - min_data) / (max_data - min_data)

    # Next, conduct model prediction on each spectral column
    labels_pred = model.predict(data_pred, verbose = 1, workers = 4)
    labels_pred = np.reshape(labels_pred,(h2,w2))

    ### Calculate threshold for classification  
    thresh = filters.threshold_otsu(labels_pred)

    ### Plot the input image alongside its corresponding predictions.
    plt.figure(figsize=(20,20))
    plt.subplot(131);plt.imshow(rgb_from_raster(data, 0.0)); plt.title(filename)
    plt.subplot(132);plt.imshow(labels_pred, cmap = 'Blues');
    # plt.colorbar()
    plt.subplot(133);plt.imshow(labels_pred > 0.4, cmap = 'Blues');
    plt.draw()
    plt.show()
    
    ### save classifications to raster
    labels_pred = labels_pred.astype(float)
    
    array_classification = labels_pred > thresh
    array_classification = array_classification.astype(float)
    
    classification_filename = '../../data/raster_classifications/classification_' + filename
    
    
    if save_classification:
        with rasterio.open(
            classification_filename,
            'w',
            driver='GTiff',
            height=labels_pred.shape[0],
            width=labels_pred.shape[1],
            count=1,
            dtype=labels_pred.dtype,
            crs='+proj=latlong',
            transform=transform,
        ) as dst:
            dst.write(labels_pred, 1)


        print('saved as: ', classification_filename)
# Out:
# ../../data/rasters_waterbodies_osm/cities/Jakarta/Jakarta_250_pansharpen_True_2019-07-23_03:16_1030010096702700.tif
# 448576/448576 [==============================] - 24s 52us/step
# saved as:  ../../data/raster_classifications/classification_Jakarta_250_pansharpen_True_2019-07-23_03:16_1030010096702700.tif
# ../../data/rasters_waterbodies_osm/cities/Jakarta/Jakarta_233_pansharpen_True_2019-07-23_03:16_1030010096702700.tif
# 349782/349782 [==============================] - 17s 47us/step
# saved as:  ../../data/raster_classifications/classification_Jakarta_233_pansharpen_True_2019-07-23_03:16_1030010096702700.tif
# ../../data/rasters_waterbodies_osm/cities/Medan/Medan_241_pansharpen_True_2020-03-03_04:05_10300100A367E500.tif
# 212926/212926 [==============================] - 9s 44us/step
# saved as:  ../../data/raster_classifications/classification_Medan_241_pansharpen_True_2020-03-03_04:05_10300100A367E500.tif

# %%
# write probabilities raster to file

with rasterio.open(
    classification_filename,
    'w',
    driver='GTiff',
    height=labels_pred.shape[0],
    width=labels_pred.shape[1],
    count=1,
    dtype=labels_pred.dtype,
    crs='+proj=latlong',
    transform=transform,
) as dst:
    dst.write(labels_pred, 1)


print('saved as: ', classification_filename)
# Out:
# saved as:  ../../TreeTect/data/raster_classifications/classification_Manila_001_2020-02-29_02:32_10300100A4711D00.tif

# %%
plt.figure(figsize = (20,20))
plt.imshow(labels_pred, cmap = 'Blues')

# %% [markdown]
# ## If no data: Get data from GBDX
#
# Skip this part if you have downloaded imagery from s3

# %%
# get setu babakan data and write to geotiff

# rawa indah = 106.885, -6.36, 106.89, -6.355 , 1030010085B5FC00
# rawa babon = 106.884, -6.341, 106.888, -6.335, 10400100503B3A00

# manila test = 121.004, 14.531, 121.007, 14.535 , 10300100A4711D00

# Shenzen = 114.07, 22.533, 114.074, 22.536 , 10300100A3350C00

from gbdxtools.task import env
from gbdxtools import CatalogImage
# %matplotlib inline

catalog_id = env.inputs.get('catalog_id', '1030010085B5FC00')
bbox = env.inputs.get('bbox', '121.006, 14.535, 121.009, 14.537 ')

image = CatalogImage(catalog_id, band_type="MS", bbox=map(float, bbox.split(",")), pansharpen = True)


import datetime



image_id = catalog_id

# Get timestamp
time_image = image.metadata["image"]["acquisitionDate"] 

# convert timestamp to datetime timestamp format
time_image = datetime.datetime.strptime(time_image, "%Y-%m-%dT%H:%M:%S.%fZ")
    
time_image_str = time_image.strftime('%Y-%m-%d_%H:%M')
# Out:
# ---------------------------------------------------------------------------
# ImageNotAvailable                         Traceback (most recent call last)
# <ipython-input-10-ca9b78ad8ee9> in <module>
#      15 bbox = env.inputs.get('bbox', '121.006, 14.535, 121.009, 14.537 ')
#      16
# ---> 17 image = CatalogImage(catalog_id, band_type="MS", bbox=map(float, bbox.split(",")), pansharpen = True)
#      18
#      19
#
# ~/anaconda3/envs/FNC_1/lib/python3.7/site-packages/gbdxtools/images/catalog_image.py in __new__(cls, cat_id, **kwargs)
#      49                 msg = '\n{} exists in Catalog but image is not in GBDX'.format(cat_id)
#      50                 msg += '\nOrder the image (see Ordering.order()) and/or wait for delivery'
# ---> 51                 raise ImageNotAvailable(msg)
#      52
#      53
#
# ImageNotAvailable:
# 1030010085B5FC00 exists in Catalog but image is not in GBDX
# Order the image (see Ordering.order()) and/or wait for delivery

# %%
name = 'Manila_roofs'

# %%
path = "../../TreeTect/data/rasters_waterbodies_osm/{}_{}_{}.tif".format(name,time_image_str,image_id)

path

tif = image.geotiff(
    path = path
                 )

# %%
path
# Out:
# '../../TreeTect/data/rasters_waterbodies_osm/Manila_roofs_2020-02-29_02:32_10300100A4711D00.tif'
